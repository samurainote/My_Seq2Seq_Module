# %% [markdown]
# ## Text Classification using Attention Mechanism in Keras

# %%
import tensorflow as tf
from keras_preprocessing import sequence
from tensorflow import keras
from tensorflow.python.keras import Input

# %% [markdown]
# ### Step1. Load imdb dataset

# %%
vocab_size = 10000

# %%
padding_id = 0
start_id = 1
oov_id = 2
index_offset = 2

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.imdb.load_data(path="imdb.npz",
                                                      num_words=vocab_size,
                                                      skip_top=0,
                                                      maxlen=None,
                                                      seed=113,
                                                      start_char=start_id,
                                                      oov_char=oov_id,
                                                      index_from=index_offset)

# %% [markdown]
# Keras has dataset which already

# %%
x_train.shape
# Out:
# (25000,)

# %%
x_train
# Out:
# array([list([1, 13, 21, 15, 42, 529, 972, 1621, 1384, 64, 457, 4467, 65, 3940, 3, 172, 35, 255, 4, 24, 99, 42, 837, 111, 49, 669, 2, 8, 34, 479, 283, 4, 149, 3, 171, 111, 166, 2, 335, 384, 38, 3, 171, 4535, 1110, 16, 545, 37, 12, 446, 3, 191, 49, 15, 5, 146, 2024, 18, 13, 21, 3, 1919, 4612, 468, 3, 21, 70, 86, 11, 15, 42, 529, 37, 75, 14, 12, 1246, 3, 21, 16, 514, 16, 11, 15, 625, 17, 2, 4, 61, 385, 11, 7, 315, 7, 105, 4, 3, 2222, 5243, 15, 479, 65, 3784, 32, 3, 129, 11, 15, 37, 618, 4, 24, 123, 50, 35, 134, 47, 24, 1414, 32, 5, 21, 11, 214, 27, 76, 51, 4, 13, 406, 15, 81, 2, 7, 3, 106, 116, 5951, 14, 255, 3, 2, 6, 3765, 4, 722, 35, 70, 42, 529, 475, 25, 399, 316, 45, 6, 3, 2, 1028, 12, 103, 87, 3, 380, 14, 296, 97, 31, 2070, 55, 25, 140, 5, 193, 7485, 17, 3, 225, 21, 20, 133, 475, 25, 479, 4, 143, 29, 5534, 17, 50, 35, 27, 223, 91, 24, 103, 3, 225, 64, 15, 37, 1333, 87, 11, 15, 282, 4, 15, 4471, 112, 102, 31, 14, 15, 5344, 18, 177, 31]),
#        list([1, 193, 1152, 193, 8254, 77, 227, 4, 5, 1462, 4368, 5011, 133, 25, 3, 714, 7, 117, 1633, 13, 393, 19, 12, 118, 953, 188, 101, 4, 206, 109, 3102, 20, 13, 68, 187, 7, 29, 22, 6, 3, 248, 125, 92, 3, 113, 8, 2299, 1522, 4, 646, 3, 115, 8, 34, 8162, 3, 228, 8, 339, 1321, 3, 117, 8, 3, 129, 4900, 18, 3, 1001, 4, 88, 28, 951, 45, 36, 3, 454, 8, 44, 42, 37, 1542, 1904, 397, 3, 1648, 25, 6852, 4, 162, 10, 3214, 2, 3, 1152, 8, 193, 774, 6, 8254, 2, 348, 2636, 147, 604, 2, 8002, 14, 122, 124, 67, 2, 6852, 14, 348, 164, 4361, 97, 4, 3, 227, 8, 42, 2, 1156, 14, 298, 119, 4, 119, 173, 10, 219, 174, 135, 49, 8, 4372, 227, 8254, 4, 2, 655, 244, 2349, 4, 3, 9836, 130, 151, 490, 17, 2, 31, 7463, 1211, 13, 8, 5, 370, 77, 21, 624, 63, 1381, 8, 7, 167, 144, 22, 3, 1689, 14, 15, 3, 1354, 4, 27, 5, 51, 153, 461, 32, 88, 77, 284, 15, 144, 94]),
#        list([1, 13, 46, 7, 29, 30, 6, 3, 248, 107, 6, 3, 5973, 53, 60, 368, 12, 70, 148, 13, 21, 111, 3, 2400, 310, 11, 15, 3710, 32, 74, 42, 1828, 295, 3, 85, 319, 34, 533, 18, 262, 4820, 1300, 3, 1872, 32, 88, 77, 11, 65, 15, 3, 359, 6, 3, 57, 315, 333, 10, 3, 1715, 42, 644, 661, 7, 256, 84, 1199, 41, 1227, 2577, 82, 67, 3911, 14, 35, 164, 1538, 277, 35, 68, 2, 779, 7, 105, 13, 6904, 1337, 17, 5, 21, 11, 214, 27, 609, 39, 5, 86, 325, 22, 2299, 20, 22, 21, 11, 271, 39, 56, 30, 10, 3, 21, 46, 5, 2306, 50, 8, 169, 22, 594, 115, 594, 1351, 12, 190, 78, 637, 88, 2, 13, 8, 7, 105, 606, 623, 34, 533, 5, 226, 6, 128, 112]),
#        ...,
#        list([1, 10, 5, 229, 244, 6400, 8, 5, 1224, 445, 2, 44, 2173, 83, 8321, 4006, 20, 3, 911, 83, 2, 324, 724, 133, 2, 1714, 83, 4, 35, 27, 56, 1098, 20, 7, 139, 7, 702, 4, 2, 83, 55, 17, 1643, 13, 8, 30, 6, 3, 9405, 1208, 2294, 2, 1007, 17, 5, 19, 206, 109, 562, 11, 7, 2900, 2, 7, 96, 5, 19, 52, 4766, 73, 3, 459, 363, 1272, 28, 269, 10, 959, 107, 44, 39, 28, 2960, 394, 10, 5, 4064, 499, 6, 2, 88, 363, 69, 28, 139, 3, 63, 4779, 10, 3, 2677, 25, 177, 3, 528, 442, 2, 4, 26, 709, 116, 2, 8122, 164, 46, 83, 36, 130, 817, 13, 594, 9, 9, 60, 1241, 1208, 9, 9, 287, 2259, 1701, 33, 2900, 2, 3, 64, 495, 3, 230, 6, 789, 4, 5, 319, 233, 2765, 233, 1118, 1573, 6, 495, 3, 138, 928, 2900, 2, 7749, 4, 4240, 17, 3, 8496, 2, 249, 10, 1817, 7560, 3, 4216, 5407, 746, 1114, 371, 1889, 1005, 540, 9302, 6, 3, 58, 2, 3, 3585, 2]),
#        list([1, 1445, 7078, 68, 71, 3304, 12, 609, 929, 7, 11, 581, 22, 4, 15, 483, 684, 53, 348, 10, 4119, 2958, 44, 57, 1465, 12, 196, 11, 15, 42, 22, 2, 4, 61, 29, 144, 401, 10, 4130, 50, 574, 31, 60, 368, 70, 65, 769, 11, 1053, 74, 99, 2197, 7, 3, 104, 36, 68, 146, 711, 74, 3542, 43, 256, 389, 4, 68, 262, 513, 104, 49, 285, 1813, 22, 3, 122, 12, 160, 39, 4, 420, 3, 115, 15, 896, 12, 2, 39, 318, 5871, 111, 6699, 10, 4802, 120, 24, 69, 3467, 3, 718, 3797, 12, 17, 30, 61, 39, 7, 7199, 3, 2, 6, 13, 122, 4, 941, 24, 7, 720, 11, 144, 4, 201, 11, 159, 579, 201, 11, 5, 51, 57, 2, 91, 400, 727, 11, 38, 13, 250, 7, 14, 250, 4, 2, 11, 37, 83, 79, 123, 11, 8, 22]),
#        list([1, 16, 5, 193, 336, 6, 3, 203, 21, 44, 253, 7, 105, 13, 122, 3, 2, 269, 2, 4, 2, 2, 731, 2097, 100, 404, 38, 13, 1033, 3, 1309, 8, 114, 49, 304, 11, 46, 3, 167, 4, 234, 6, 37, 110, 698, 101, 6, 3, 4038, 9244, 8, 23, 5, 77, 1098, 16, 2344, 2, 20, 26, 9684, 6138, 4, 2, 1602, 91, 1182, 3, 1309, 6, 3, 203, 41, 96, 89, 34, 220, 108, 28, 126, 26, 117, 7, 96, 11, 156, 20, 6788, 2, 8, 5, 65, 77, 1098, 3, 630, 1190, 4, 2641, 271, 190, 1069, 5, 7584, 7, 2196, 2, 2, 543, 4, 382, 1270, 847, 1467, 2, 496, 2, 7, 1596, 8777, 2, 20, 59, 26, 238, 8, 42, 8367, 208, 404, 9, 9, 11, 763, 39, 3, 247, 19, 11, 15, 4, 173, 1790, 71, 6, 50, 5, 1738, 21, 3, 203, 130, 8])],
#       dtype=object)

# %%
word2idx = tf.keras.datasets.imdb.get_word_index()

# %%
len(word2idx)
# Out:
# 88584

# %%
word2idx
# Out:
# {'ahead': 1401,
#  'autopsied': 72570,
#  'liberatore': 52427,
#  'daines': 35785,
#  'spt11': 70739,
#  'faggoty': 63940,
#  'plow': 58779,
#  'laughless': 45087,
#  'twitty': 49744,
#  'reductionism': 78372,
#  'expectedly': 40096,
#  'ides': 59207,
#  'anyhoo': 26419,
#  "schygulla's": 53063,
#  'apollonius': 62412,
#  'postrevolutionary': 46238,
#  "mendez'": 83495,
#  'confessions': 12053,
#  "anymore'": 52384,
#  'logging': 31356,
#  "sharks'": 67979,
#  'persona': 3567,
#  'blech': 23529,
#  'actess': 85702,
#  'ishtar': 17345,
#  'augmenting': 68795,
#  'simplify': 40874,
#  "typewriter's": 57195,
#  'rollo': 25648,
#  'pia': 8745,
#  'awsome': 23012,
#  'symbolizes': 16511,
#  "brave'": 85200,
#  'donut': 21482,
#  'stinkers': 16017,
#  'depict': 6354,
#  'disrobe': 26274,
#  'repulse': 35238,
#  "ferula's": 53495,
#  '3p0': 77127,
#  'pe': 49011,
#  'pearson': 32271,
#  'assumption': 10878,
#  'stainless': 39858,
#  'fostering': 34553,
#  'an': 32,
#  'bellows': 26351,
#  "che's": 7258,
#  'postponement': 75376,
#  'rerecorded': 71012,
#  'wondrous': 9830,
#  'nickles': 59065,
#  "heath's": 73413,
#  'plainspoken': 37965,
#  "rostotsky's": 69880,
#  'giveaway': 24185,
#  'stammering': 24705,
#  'ality': 82317,
#  'pardons': 86123,
#  'sends': 3289,
#  'todays': 8841,
#  'sanctifies': 56419,
#  'camping': 7790,
#  "fiancée's": 35894,
#  'scots': 18606,
#  'antionioni': 82312,
#  "bruce's": 14213,
#  'washoe': 47230,
#  "'robin's": 74097,
#  'miffed': 45955,
#  'mahalovic': 58544,
#  'sturm': 36198,
#  'recoil': 24348,
#  'policing': 27142,
#  'ascends': 36415,
#  'tomilson': 55966,
#  'summerson': 82836,
#  'lala': 57236,
#  'rousset': 58232,
#  "ismael's": 36776,
#  'disagreeable': 33139,
#  '92fs': 70724,
#  'tyaga': 54531,
#  'darma': 88417,
#  'midwestern': 20784,
#  'nitwits': 43387,
#  'epoch': 42609,
#  "'beau": 87892,
#  'sadomania': 61677,
#  'baokar': 85123,
#  'gentrification': 55900,
#  'fireplaces': 42471,
#  'sofa': 19463,
#  "kareeena's": 86252,
#  'formations': 71108,
#  'brillant': 44466,
#  'dears': 82695,
#  "'panda'": 64451,
#  'brett': 7577,
#  "l'argent": 61431,
#  'sunniest': 60507,
#  "'youth'": 74713,
#  "ahmed's": 84387,
#  'umpteenth': 22876,
#  'diverged': 50335,
#  'adulterate': 85839,
#  'unduly': 26906,
#  'enacting': 21619,
#  'formats': 21728,
#  'gassing': 40814,
#  'showcase': 4699,
#  'commemorative': 74254,
#  'yawner': 26874,
#  "hefti's": 79427,
#  'completley': 37566,
#  'footling': 53825,
#  'malini': 76415,
#  'marginalized': 27054,
#  'klembecker': 63228,
#  'imagines': 11935,
#  "'imitating'": 86284,
#  'kalser': 70781,
#  'intrusion': 17339,
#  'carolina': 13473,
#  'lupa': 47510,
#  'recruiting': 16447,
#  'cimmerian': 61484,
#  'awesome': 1187,
#  'contract': 3481,
#  'meador': 70686,
#  'brumes': 88514,
#  "monster'": 33718,
#  'wannabes': 14774,
#  'chanting': 16737,
#  "roses'so": 64051,
#  "someone's": 4469,
#  "berlin's": 40208,
#  'yas': 44214,
#  'munched': 36221,
#  'failures': 7991,
#  'irremediably': 52367,
#  '2001': 3042,
#  'bao': 68074,
#  'paraphrase': 13202,
#  'pattes': 63343,
#  "'debacle'": 86144,
#  'needs': 735,
#  'songwriter': 13885,
#  'clammy': 72975,
#  'disruption': 37047,
#  'unfussy': 64511,
#  "'noir'": 43755,
#  'axed': 23919,
#  'phipps': 36397,
#  'gnarly': 25923,
#  'refuse': 5991,
#  "''little''": 58164,
#  'peerless': 34956,
#  'strangelove': 11462,
#  'haunted': 2365,
#  'upswing': 58477,
#  "year's": 4972,
#  'communities': 10999,
#  'lice': 32903,
#  'florence': 13945,
#  'anupam': 17271,
#  'nitrous': 35064,
#  'aa': 30093,
#  'doorknob': 30135,
#  "nemesis'": 88572,
#  'ying': 23646,
#  'cv': 16218,
#  'grin': 7838,
#  'preconceived': 19613,
#  'skateboards': 43788,
#  'bhatt': 34195,
#  'spangled': 47581,
#  'employment': 10705,
#  'perspectives': 8350,
#  "'favorite": 71240,
#  'hypnosis': 17536,
#  'retaliates': 36934,
#  'franck': 51344,
#  'maximizes': 47044,
#  "'spilling": 59654,
#  'phenomena': 13541,
#  'bertie': 33075,
#  'newcombe': 10613,
#  'discontentment': 71359,
#  'hypnotherapy': 60305,
#  'hoofing': 31498,
#  'pliable': 56950,
#  'robards': 22903,
#  "orb's": 73251,
#  'bombed': 8488,
#  'sender': 31160,
#  'synchronous': 33156,
#  'finders': 64379,
#  '9': 787,
#  'double': 1402,
#  'monotone': 10522,
#  'foment': 58309,
#  'worse': 430,
#  "'poets": 84882,
#  'seriously\x85': 49806,
#  'tches': 80983,
#  'gape': 48914,
#  'muscleheads': 65624,
#  'laguna': 56697,
#  'christansan': 71583,
#  'sound': 478,
#  'assortment': 9151,
#  'versois': 53010,
#  'flack': 23738,
#  'unowns': 65397,
#  'reabsorbed': 68811,
#  'dreamed': 10175,
#  "lollo's": 59568,
#  'fountains': 38122,
#  'seductive': 6920,
#  'destructible': 70577,
#  'mounties': 22042,
#  'philp': 67833,
#  'standa': 32527,
#  'particulary': 42880,
#  'demoniac': 64091,
#  "coffy's": 41691,
#  'disinterred': 56235,
#  'danse': 26145,
#  'satya': 22381,
#  'filmmakes': 56462,
#  'valet': 21481,
#  'nonstraight': 62485,
#  'juscar': 86372,
#  "bogart's": 32075,
#  'galactic': 20859,
#  "'newest'": 53733,
#  'agnes': 13255,
#  'indistinguishable': 14471,
#  'inn': 12518,
#  'tradeoff': 87046,
#  "'cradle": 73676,
#  'criticizing': 11429,
#  'gameel': 88216,
#  'poodle': 17956,
#  'courageously': 46546,
#  'prevailed': 21936,
#  'hipocracy': 67835,
#  'resourcefully': 88231,
#  "domination'": 39051,
#  'cranium': 80688,
#  'compensated': 12343,
#  'films': 105,
#  'eventhough': 58210,
#  'raitt': 49167,
#  "normal'": 61642,
#  'profusion': 84914,
#  'canons': 32963,
#  'transmitted': 16093,
#  'goggenheim': 85514,
#  "'stop'": 59374,
#  'sliced': 14389,
#  'ratchet': 29333,
#  'misstated': 87358,
#  "89's": 56244,
#  'guardano': 65238,
#  'cloak': 8098,
#  "tamblyn's": 78001,
#  'woar': 84182,
#  'vinod': 42979,
#  'hunchbacked': 73681,
#  'jingle': 25736,
#  'hanley': 64784,
#  "kristofferson's": 20257,
#  "contractor's": 68656,
#  "claudette's": 84909,
#  '1901': 33569,
#  'demarcation': 60207,
#  'professor': 2486,
#  'kaminska': 30651,
#  "méliès'": 52519,
#  'payal': 58371,
#  "goodspeed'": 72519,
#  'mecca': 16580,
#  'trawled': 76235,
#  'mirrors\x85': 81157,
#  'linklater': 17070,
#  'ride': 1362,
#  'subdue': 25299,
#  "roth'": 65597,
#  'ante': 21655,
#  "'all'": 56832,
#  "stevens'": 65750,
#  'envisages': 67890,
#  'coys': 48475,
#  'larded': 42583,
#  'magus': 88471,
#  "binoche's": 87138,
#  'shinji': 25098,
#  'mango': 41437,
#  "duologue's": 54763,
#  'whisking': 37501,
#  "'pando'": 79498,
#  'langa': 61161,
#  'poalher': 49058,
#  'sake': 2116,
#  'shores': 26744,
#  'retelling': 9211,
#  'technical': 1756,
#  'melania': 56541,
#  'details\x85': 70752,
#  'swearengen': 74765,
#  'jutland': 67393,
#  'finding': 1553,
#  'biko': 5494,
#  'winnipeg': 40304,
#  'fangled': 35401,
#  'kegan': 35203,
#  'mccarthy': 7584,
#  'proposal': 12356,
#  'nez': 76931,
#  'filmgoers': 21242,
#  'often': 397,
#  'argo': 49565,
#  'validates': 28468,
#  'impromptu': 15755,
#  'exterminated': 41722,
#  'sleazebags': 60833,
#  "bodyguard's": 53025,
#  'mentored': 42221,
#  'spongy': 47536,
#  'dejected': 30357,
#  'hannigan': 44270,
#  "miz's": 71246,
#  'izuruha': 51738,
#  'hasta': 43916,
#  "grot'": 25935,
#  'upright': 15712,
#  'rig': 18496,
#  'franticly': 80783,
#  'eeeevil': 72586,
#  'relocations': 84472,
#  'readjust': 87840,
#  "felt'": 76047,
#  'bullet': 3982,
#  'startle': 40665,
#  'colors': 2508,
#  'strindberg': 18277,
#  'wastepaper': 70733,
#  "b's": 28839,
#  'virginhood': 53786,
#  'telemachus': 39313,
#  'bacterium': 80304,
#  'plod': 22664,
#  'pentagrams': 42228,
#  'solved': 8071,
#  'yer': 21327,
#  'tux': 29671,
#  'whotta': 53254,
#  'shakur': 44431,
#  'micawbers': 80713,
#  "'calm'": 52414,
#  'politician': 5851,
#  'seashell': 65690,
#  'panorama': 21612,
#  'dirtiness': 61895,
#  "silverman's": 87693,
#  'byu': 40788,
#  'schmoke': 48805,
#  'medicated': 31273,
#  'qing': 83390,
#  'bedpost': 64144,
#  'oceanfront': 66374,
#  'rotten': 4455,
#  'konchalovski': 73157,
#  'barbeau': 19866,
#  'theorist': 33067,
#  'familiarity': 10417,
#  "stageplay's": 81757,
#  'yummm': 77202,
#  'manged': 50757,
#  "90't": 66522,
#  'sauna': 41795,
#  "this'll": 74711,
#  'frisk': 81537,
#  "'cop'": 66135,
#  'sipple': 58141,
#  'spacefaring': 67878,
#  'redifined': 42188,
#  'hitting': 3343,
#  'gloaming': 62142,
#  'tsing': 15025,
#  "intense'": 86705,
#  'topical': 15678,
#  'tasteless': 5454,
#  'amerikan': 81580,
#  'chromatic': 65876,
#  'slides': 13758,
#  'hearing': 2228,
#  'crayons': 40615,
#  'goy': 63783,
#  'strenghtens': 84762,
#  'teamings': 81889,
#  'pseudo': 3902,
#  'astricky': 73123,
#  'shudder': 10828,
#  'immaturely': 81469,
#  'grossout': 83580,
#  'shipiro': 81495,
#  'oddjob': 59455,
#  'laundress': 82580,
#  'omid': 43027,
#  'loffe': 65531,
#  'titillate': 22665,
#  'steeple': 40286,
#  'krige': 13387,
#  'ummmm': 68256,
#  'aortic': 49398,
#  'recreates': 19059,
#  'prepon': 25587,
#  'claiborne': 86671,
#  'whales': 15562,
#  'causal': 38674,
#  'lillihamer': 87174,
#  'mayer': 12609,
#  'floods': 26155,
#  'akroyd': 41530,
#  'boobage': 52052,
#  'gooledyspook': 54308,
#  "helsing's": 35205,
#  'as': 14,
#  'capitalizes': 26915,
#  'moonlight': 15828,
#  "chiles'": 75975,
#  'celi': 45606,
#  'enticements': 77231,
#  "capshaw's": 44372,
#  "'homily'": 75673,
#  'tremendous': 3536,
#  'animatronics': 29555,
#  "'43": 44167,
#  'fiancè': 76842,
#  "smiley's": 43406,
#  'melville´s': 87484,
#  'worldliness': 42231,
#  'naschy': 6638,
#  "outbreak'": 64597,
#  'darwin': 26261,
#  'fe': 33291,
#  'finese': 77847,
#  'playgroung': 67704,
#  "'angel": 66098,
#  'stereotype': 4372,
#  'hollister': 35994,
#  'ash': 9494,
#  'outlined': 23873,
#  'parallelism': 43710,
#  "bettany's": 52440,
#  'examp': 73895,
#  'muddah': 74235,
#  'rudeness': 34239,
#  'itÕs': 65631,
#  'producer9and': 53184,
#  "'item": 82597,
#  'bromfield': 25779,
#  'clipper': 61951,
#  'humor\x85of': 81525,
#  'crafts': 16327,
#  'stone': 1651,
#  "i'am": 69514,
#  'mejding': 51480,
#  'tartakovsky': 76365,
#  "'cartoons'": 51979,
#  "pay'": 87850,
#  'heigl': 22001,
#  "europa'": 54917,
#  'objectifier': 82629,
#  'gaijin': 51927,
#  'therefore': 1614,
#  'attentive': 20028,
#  'joseph': 2312,
#  "policewoman's": 66337,
#  "stepfather's": 53972,
#  'vane': 36725,
#  'cia': 3729,
#  'consultation': 76587,
#  'mixing': 6093,
#  "mastroianni's": 33511,
#  'francescoantonio': 66752,
#  'worshipful': 55470,
#  'ladder': 5401,
#  'entranced': 13560,
#  'rockumentaries': 54212,
#  'whitebread': 49786,
#  'wildside': 34448,
#  'frolick': 80228,
#  'prevailing': 16864,
#  "sandrich's": 51660,
#  'crassness': 56233,
#  'bartend': 66488,
#  'unpretentious': 11374,
#  'complied': 62777,
#  'marius': 18228,
#  'folksy': 22478,
#  'snatched': 14967,
#  'unused': 20478,
#  'sherry': 11284,
#  'rubberneck': 36162,
#  'nymph': 21316,
#  'serlingesque': 66825,
#  'empowered': 28886,
#  '150': 9814,
#  'sagemiller': 18841,
#  "'blacky'": 64788,
#  'pv': 78723,
#  'hilarius': 45825,
#  'cider': 32954,
#  'hordes': 12414,
#  'lapped': 47277,
#  'abortionists': 41339,
#  "zeroni's": 52941,
#  'meticulous': 14969,
#  'impalements': 50054,
#  "feel'": 46967,
#  'schtick': 10402,
#  'bbs': 51971,
#  'trashbin': 74642,
#  'cinephile': 31479,
#  'abeyance': 56447,
#  'houseguest': 63065,
#  'pedicab': 21124,
#  'racketeer': 51630,
#  'tritely': 58523,
#  'extinguisher': 22969,
#  'hydrochloric': 42989,
#  'ford': 2105,
#  'halfassing': 52270,
#  'peggie': 81453,
#  'unsubstantial': 41077,
#  '1958': 7550,
#  "esra's": 59005,
#  "msmyth's": 66650,
#  'seeding': 79535,
#  'giusstissia': 61916,
#  "molnar's": 79371,
#  'vexing': 70534,
#  'crappiness': 27331,
#  'adventurous': 9581,
#  "'toxic": 65392,
#  'dissectionist': 78517,
#  'hylands': 88103,
#  'gnomes': 38718,
#  'briliant': 72813,
#  'khazzan': 57217,
#  'isabell': 49030,
#  'peugeot': 77463,
#  'ziv': 40199,
#  'peww': 83646,
#  'bow': 5628,
#  'lucrencia': 59371,
#  'polygamy': 27175,
#  'seitz': 50479,
#  'axiom': 46133,
#  "day's": 9969,
#  'assaulter': 53790,
#  'confirmation': 24481,
#  'cathay': 77653,
#  "86'": 68678,
#  'cassinelli': 47533,
#  "erroll's": 40325,
#  'raspberry': 34380,
#  'guests': 5537,
#  'shingon': 65451,
#  'kanin': 20722,
#  'montano': 24606,
#  'irreparably': 28532,
#  '1300': 61493,
#  'insectoid': 51258,
#  'rocsi': 79651,
#  'yammering': 41289,
#  '36th': 23881,
#  'boone\x85': 54274,
#  'manicotti': 43497,
#  "cbs's": 43552,
#  'dispensable': 39014,
#  'anymore': 1624,
#  'majkowski': 31372,
#  'unferth': 38359,
#  'ttono': 43981,
#  'saddled': 12576,
#  'snafu': 13601,
#  'who\x97like': 85896,
#  "'explaining": 67115,
#  "leung's": 68088,
#  "sonny's": 80213,
#  'dragooned': 81555,
#  'bulletins': 39880,
#  'synchronize': 36858,
#  'tughlaq': 67728,
#  "r'n'b": 74257,
#  'dibnah': 81492,
#  'adopting': 21639,
#  'merging': 20300,
#  "'decency'": 67483,
#  'feisty': 10635,
#  'taxman': 58272,
#  "keitel's": 49176,
#  'retell': 34840,
#  'jetee': 43333,
#  "cutter's": 67404,
#  'vanishings': 71816,
#  'underact': 51597,
#  'archaeology': 32504,
#  'relgious': 86279,
#  'photoshopped': 78931,
#  'rebe': 74320,
#  'squeezed': 23518,
#  'snipers': 14694,
#  "o'hara's": 31697,
#  'kudrow': 14438,
#  'trooper': 19857,
#  'pointe': 15584,
#  'woodlands': 35628,
#  "'cool'": 38793,
#  'tac': 40787,
#  'confesses': 11302,
#  'minimise': 38902,
#  'infrastructure': 35168,
#  'kumars': 47517,
#  'cristiana': 61897,
#  'alisande': 44793,
#  'benito': 23142,
#  'konnvitz': 59131,
#  'pivot': 41005,
#  'syncing': 27440,
#  'ladyship': 68323,
#  'stunner': 25099,
#  'kheymeh': 84974,
#  'confidence': 4451,
#  'préjean': 72925,
#  'dwars': 72822,
#  'bambi': 18863,
#  'pastel': 21971,
#  'airbag': 46497,
#  'waddell': 40911,
#  'illogicalities': 58914,
#  'secede': 46461,
#  'bakersfeild': 53031,
#  'prior': 2597,
#  "rave'": 59616,
#  'pernell': 22566,
#  'relentlessy': 60541,
#  'lionel': 6991,
#  'jilt': 54010,
#  "clarke's": 23638,
#  "argentine'": 75294,
#  'employing': 16187,
#  'catalunya': 37407,
#  'chuckles': 7608,
#  'royce': 19435,
#  'hj': 52059,
#  'versatile': 9203,
#  'papaya': 44635,
#  'ferrets': 62938,
#  'ususally': 58684,
#  'katic': 52789,
#  'bushwacker': 63550,
#  'constructs': 22723,
#  'vosen': 34496,
#  'acapulco': 32410,
#  'cleanup': 43059,
#  'veered': 37328,
#  '1775': 54369,
#  'hone': 30591,
#  "ross's": 62011,
#  'anathema': 35194,
#  'hemlock': 81708,
#  'bleu': 74834,
#  'nx': 33520,
#  "'snowwhite'": 84167,
#  "karin's": 61898,
#  "'rush": 40560,
#  'commandments': 13177,
#  'till': 2446,
#  'kleban': 55446,
#  'knockoffs': 33114,
#  'psychiatry': 28779,
#  'prosthesis': 73990,
#  "sassy's": 56922,
#  'sabato': 25600,
#  "'superfluous'": 62922,
#  'hooded': 23962,
#  'trueblood': 43659,
#  "it'good": 52469,
#  'enfilren': 56281,
#  'dvdtalk': 71500,
#  'hackensack': 62259,
#  "jodie's": 45442,
#  'vivant': 39053,
#  'imperiousness': 70366,
#  'merlot': 46705,
#  "nature'": 40875,
#  'firmer': 47846,
#  'overused': 11028,
#  'exemplifying': 39866,
#  'desegregation': 70966,
#  'backdropped': 87756,
#  "hobson's": 63822,
#  'dumitru': 47739,
#  'incorporating': 16527,
#  "'bonjour": 51594,
#  "blankfield's": 63592,
#  'calhoun': 16240,
#  'nris': 82011,
#  'mastrontonio': 63458,
#  "'actor'": 46795,
#  'scenarios': 7287,
#  'ingratiate': 33441,
#  'morand': 24977,
#  'tangled': 11946,
#  "revenge'": 49280,
#  'crisp': 6361,
#  'beirut': 25765,
#  'suckingly': 64328,
#  'wranglers': 63100,
#  'doren': 29396,
#  'pei': 20868,
#  "escape'": 76684,
#  'executive': 3512,
#  'undercurrent': 15359,
#  'comedygenre': 75583,
#  'expulsion': 25157,
#  'coffins': 25449,
#  'shani': 22291,
#  'bangladesh': 29271,
#  'reek': 22517,
#  "'muck'": 75480,
#  'minis': 27611,
#  'barred': 14625,
#  "tulkinhorn's": 36331,
#  'nautilus': 62646,
#  'pitchers': 76566,
#  'unprofessionally': 71751,
#  "zenia's": 30199,
#  'idap': 46016,
#  'disintegration': 24670,
#  'demonicly': 54172,
#  'ones\x97with': 82128,
#  "mecha's": 75137,
#  'piaf': 28424,
#  'piling': 19368,
#  'distorted': 8560,
#  "luc's": 30621,
#  'hugs': 20613,
#  'payoff': 7444,
#  'dosed': 31681,
#  'robe': 13194,
#  "don's": 15793,
#  'smooshed': 67217,
#  'mindless': 3088,
#  'incorporates': 13699,
#  'spectacular': 2090,
#  'offering': 3988,
#  'prowls': 30961,
#  'petrus': 59900,
#  "'lets": 84346,
#  'necrotic': 74989,
#  'emptiest': 81111,
#  'fartsys': 66261,
#  'delinquency': 19999,
#  'asshole': 19766,
#  'worthy': 1514,
#  'scandanavian': 36609,
#  'denominations': 73246,
#  'stefanovic': 88228,
#  'balletic': 48531,
#  'jlu': 86045,
#  'implanted': 18435,
#  'striked': 63759,
#  'elizbethan': 73734,
#  'connory': 75562,
#  "daughter's": 5566,
#  'conforming': 42009,
#  'wotw': 48217,
#  'cowhands': 59823,
#  'slept': 8349,
#  'wimpish': 60414,
#  'creditability': 79128,
#  'unconquerable': 71839,
#  'albot': 65258,
#  "'gentleman's": 78641,
#  'burned': 3862,
#  'floyd': 13108,
#  'lurie': 58799,
#  'low': 361,
#  'organiser': 83222,
#  'harriett': 56125,
#  'ex': 1230,
#  'hoped': 3202,
#  'sir': 2685,
#  'pattern': 6478,
#  'gent': 32818,
#  'bristle': 54887,
#  'zhuangzhuang': 50010,
#  'fibre': 42267,
#  "forgiven'": 78280,
#  'mccathy': 77042,
#  'moed': 70254,
#  'cunningly': 20211,
#  'thespians': 17826,
#  'smack': 10751,
#  "schriber's": 73309,
#  'auction': 16268,
#  'cardiff': 41544,
#  'dealings': 14868,
#  'kenn': 87785,
#  'undergrounds': 72906,
#  'mutation': 26580,
#  "bondage's": 76656,
#  'thebom': 66955,
#  "temple'": 85260,
#  'asap': 21232,
#  'lodz': 87409,
#  'trimming': 26599,
#  'dumper': 57575,
#  'goobacks': 60359,
#  'piedras': 25895,
#  'industrialisation': 80138,
#  'sardarji': 83284,
#  'local': 716,
#  'macedonian': 39032,
#  'entices': 34975,
#  'cowboy': 2535,
#  'pansies': 58311,
#  'reside': 20182,
#  'emigré': 66832,
#  'airlines': 27340,
#  'jugoslavia': 43812,
#  'disobeyed': 55027,
#  'lurches': 18630,
#  'happend': 73542,
#  "herapheri's": 53858,
#  'madeira': 75876,
#  "akin's": 75647,
#  'davil': 75598,
#  'herrmann': 26113,
#  'someome': 52386,
#  'comparably': 36565,
#  'paternalism': 64713,
#  'dresler': 49665,
#  'geronimi': 86630,
#  "'variety'": 59351,
#  'viola': 21080,
#  'friends': 366,
#  'fenn': 44361,
#  'surveillance': 14075,
#  'colleges': 17296,
#  'bartholomew': 49329,
#  'ponds': 41374,
#  'plugging': 26876,
#  "o'rorke": 70539,
#  'overhauled': 56301,
#  "meighan's": 75459,
#  'soberingly': 83557,
#  'loom': 28519,
#  'incessant': 11050,
#  'uncapturable': 55979,
#  'display': 2441,
#  "roth's": 19677,
#  "1997'": 52116,
#  'chich': 55175,
#  'scetchy': 57990,
#  'nell': 10146,
#  'disprove': 26301,
#  'scraggy': 49700,
#  'barfing': 36072,
#  'toddlers': 26416,
#  "'docudrama'": 69873,
#  'averagely': 32237,
#  'icicles': 34002,
#  'drunkards': 46844,
#  'cravat': 54570,
#  'wrong\x85': 60138,
#  "pike's": 40074,
#  '«the': 62832,
#  'miscasted': 81364,
#  'number': 609,
#  'fab': 16468,
#  "sartain's": 52408,
#  'shrine\x85shrine': 84437,
#  'capping': 40714,
#  'charcters': 69922,
#  'grotty': 57802,
#  'invoked': 26161,
#  'blai': 50670,
#  'toaster': 24047,
#  'clarion': 79137,
#  'lin': 8589,
#  'o1': 60204,
#  'nicknames': 32796,
#  'shyster': 25446,
#  'saiba': 60550,
#  'sexualities': 41718,
#  'despicable': 5704,
#  'unladylike': 71629,
#  'affective': 39097,
#  "'ozzy": 85864,
#  "prague'": 38276,
#  'fantasically': 78976,
#  'womanizer': 16005,
#  'rem': 62036,
#  '4o': 70710,
#  'focused': 2459,
#  "day''": 45190,
#  'toro': 9508,
#  'lumsden': 71270,
#  'vacantly': 46935,
#  'revue': 13609,
#  "'horny": 61575,
#  "fart'": 61299,
#  'presence': 1366,
#  '12\x9614': 76327,
#  "moviegoer's": 63577,
#  'wyman': 46490,
#  'subtly': 6081,
#  'frenzy': 9156,
#  'persuaded': 16772,
#  'chocolat': 13644,
#  'duelling': 28899,
#  'myer': 47512,
#  'discomfort': 15480,
#  'guevara': 9522,
#  'veneration': 67401,
#  'hubbie': 44999,
#  'lippo': 85604,
#  'provincial': 16390,
#  'quelled': 48327,
#  'jet': 3702,
#  'hurling': 21228,
#  'vicky': 17336,
#  "tucker'": 84949,
#  'compete': 6110,
#  "matlin's": 33667,
#  'trove': 24141,
#  'trovajoly': 72492,
#  'advert': 16503,
#  "potente's": 37764,
#  'baseballs': 42564,
#  'shocks': 7636,
#  'manoeuvers': 64402,
#  'cannibalistic': 12426,
#  "neck's": 56315,
#  'parenthesis': 68056,
#  'housewife': 5858,
#  'radiofreccia': 29035,
#  'thorny': 42933,
#  'rosso': 52501,
#  'tuff': 37086,
#  'irreverant': 70922,
#  'naturalizing': 77978,
#  'swamps': 32920,
#  "sculptor's": 63038,
#  "bashki's": 66271,
#  'dildos': 44576,
#  'recordings': 15050,
#  'conniptions': 55192,
#  'pai': 86645,
#  "lavigne's": 62038,
#  'stirba': 14959,
#  'commemorations': 79021,
#  'queries': 31516,
#  'predominately': 47600,
#  '£300': 75032,
#  'flask': 73386,
#  'banquet': 18440,
#  'amazing': 477,
#  'oregon': 14032,
#  'stating': 7123,
#  'inconsistent\x85': 76672,
#  'liné': 85704,
#  'comparison\x97are': 68507,
#  "vengeance'": 69071,
#  'zomcoms': 83079,
#  'kingsley': 9441,
#  'discrete': 36734,
#  'disintegrate': 29636,
#  'beren': 60230,
#  "cliché's": 18794,
#  "superhero's": 64721,
#  'glitters': 88227,
#  'novotna': 41612,
#  'tomassi': 65632,
#  'tijuco': 49428,
#  "woolsey's": 70974,
#  'effigy': 66361,
#  'misgivings': 20410,
#  'ralphie': 22344,
#  'risa': 46087,
#  'tattoe': 52992,
#  "allison's": 85831,
#  ...}

# %%
idx2word = {v + index_offset: k for k, v in word2idx.items()}

idx2word[padding_id] = "<PAD>"
idx2word[start_id] = "<START>"
idx2word[oov_id] = "<OOV>" # out of vocablary

# %%
len(idx2word)
# Out:
# 88587

# %%
idx2word
# Out:
# {0: '<PAD>',
#  1: '<START>',
#  2: '<OOV>',
#  3: 'the',
#  4: 'and',
#  5: 'a',
#  6: 'of',
#  7: 'to',
#  8: 'is',
#  9: 'br',
#  10: 'in',
#  11: 'it',
#  12: 'i',
#  13: 'this',
#  14: 'that',
#  15: 'was',
#  16: 'as',
#  17: 'for',
#  18: 'with',
#  19: 'movie',
#  20: 'but',
#  21: 'film',
#  22: 'on',
#  23: 'not',
#  24: 'you',
#  25: 'are',
#  26: 'his',
#  27: 'have',
#  28: 'he',
#  29: 'be',
#  30: 'one',
#  31: 'all',
#  32: 'at',
#  33: 'by',
#  34: 'an',
#  35: 'they',
#  36: 'who',
#  37: 'so',
#  38: 'from',
#  39: 'like',
#  40: 'her',
#  41: 'or',
#  42: 'just',
#  43: 'about',
#  44: "it's",
#  45: 'out',
#  46: 'has',
#  47: 'if',
#  48: 'some',
#  49: 'there',
#  50: 'what',
#  51: 'good',
#  52: 'more',
#  53: 'when',
#  54: 'very',
#  55: 'up',
#  56: 'no',
#  57: 'time',
#  58: 'she',
#  59: 'even',
#  60: 'my',
#  61: 'would',
#  62: 'which',
#  63: 'only',
#  64: 'story',
#  65: 'really',
#  66: 'see',
#  67: 'their',
#  68: 'had',
#  69: 'can',
#  70: 'were',
#  71: 'me',
#  72: 'well',
#  73: 'than',
#  74: 'we',
#  75: 'much',
#  76: 'been',
#  77: 'bad',
#  78: 'get',
#  79: 'will',
#  80: 'do',
#  81: 'also',
#  82: 'into',
#  83: 'people',
#  84: 'other',
#  85: 'first',
#  86: 'great',
#  87: 'because',
#  88: 'how',
#  89: 'him',
#  90: 'most',
#  91: "don't",
#  92: 'made',
#  93: 'its',
#  94: 'then',
#  95: 'way',
#  96: 'make',
#  97: 'them',
#  98: 'too',
#  99: 'could',
#  100: 'any',
#  101: 'movies',
#  102: 'after',
#  103: 'think',
#  104: 'characters',
#  105: 'watch',
#  106: 'two',
#  107: 'films',
#  108: 'character',
#  109: 'seen',
#  110: 'many',
#  111: 'being',
#  112: 'life',
#  113: 'plot',
#  114: 'never',
#  115: 'acting',
#  116: 'little',
#  117: 'best',
#  118: 'love',
#  119: 'over',
#  120: 'where',
#  121: 'did',
#  122: 'show',
#  123: 'know',
#  124: 'off',
#  125: 'ever',
#  126: 'does',
#  127: 'better',
#  128: 'your',
#  129: 'end',
#  130: 'still',
#  131: 'man',
#  132: 'here',
#  133: 'these',
#  134: 'say',
#  135: 'scene',
#  136: 'while',
#  137: 'why',
#  138: 'scenes',
#  139: 'go',
#  140: 'such',
#  141: 'something',
#  142: 'through',
#  143: 'should',
#  144: 'back',
#  145: "i'm",
#  146: 'real',
#  147: 'those',
#  148: 'watching',
#  149: 'now',
#  150: 'though',
#  151: "doesn't",
#  152: 'years',
#  153: 'old',
#  154: 'thing',
#  155: 'actors',
#  156: 'work',
#  157: '10',
#  158: 'before',
#  159: 'another',
#  160: "didn't",
#  161: 'new',
#  162: 'funny',
#  163: 'nothing',
#  164: 'actually',
#  165: 'makes',
#  166: 'director',
#  167: 'look',
#  168: 'find',
#  169: 'going',
#  170: 'few',
#  171: 'same',
#  172: 'part',
#  173: 'again',
#  174: 'every',
#  175: 'lot',
#  176: 'cast',
#  177: 'us',
#  178: 'quite',
#  179: 'down',
#  180: 'want',
#  181: 'world',
#  182: 'things',
#  183: 'pretty',
#  184: 'young',
#  185: 'seems',
#  186: 'around',
#  187: 'got',
#  188: 'horror',
#  189: 'however',
#  190: "can't",
#  191: 'fact',
#  192: 'take',
#  193: 'big',
#  194: 'enough',
#  195: 'long',
#  196: 'thought',
#  197: "that's",
#  198: 'both',
#  199: 'between',
#  200: 'series',
#  201: 'give',
#  202: 'may',
#  203: 'original',
#  204: 'own',
#  205: 'action',
#  206: "i've",
#  207: 'right',
#  208: 'without',
#  209: 'always',
#  210: 'times',
#  211: 'comedy',
#  212: 'point',
#  213: 'gets',
#  214: 'must',
#  215: 'come',
#  216: 'role',
#  217: "isn't",
#  218: 'saw',
#  219: 'almost',
#  220: 'interesting',
#  221: 'least',
#  222: 'family',
#  223: 'done',
#  224: "there's",
#  225: 'whole',
#  226: 'bit',
#  227: 'music',
#  228: 'script',
#  229: 'far',
#  230: 'making',
#  231: 'guy',
#  232: 'anything',
#  233: 'minutes',
#  234: 'feel',
#  235: 'last',
#  236: 'since',
#  237: 'might',
#  238: 'performance',
#  239: "he's",
#  240: '2',
#  241: 'probably',
#  242: 'kind',
#  243: 'am',
#  244: 'away',
#  245: 'yet',
#  246: 'rather',
#  247: 'tv',
#  248: 'worst',
#  249: 'girl',
#  250: 'day',
#  251: 'sure',
#  252: 'fun',
#  253: 'hard',
#  254: 'woman',
#  255: 'played',
#  256: 'each',
#  257: 'found',
#  258: 'anyone',
#  259: 'having',
#  260: 'although',
#  261: 'especially',
#  262: 'our',
#  263: 'believe',
#  264: 'course',
#  265: 'comes',
#  266: 'looking',
#  267: 'screen',
#  268: 'trying',
#  269: 'set',
#  270: 'goes',
#  271: 'looks',
#  272: 'place',
#  273: 'book',
#  274: 'different',
#  275: 'put',
#  276: 'ending',
#  277: 'money',
#  278: 'maybe',
#  279: 'once',
#  280: 'sense',
#  281: 'reason',
#  282: 'true',
#  283: 'actor',
#  284: 'everything',
#  285: "wasn't",
#  286: 'shows',
#  287: 'dvd',
#  288: 'three',
#  289: 'worth',
#  290: 'year',
#  291: 'job',
#  292: 'main',
#  293: 'someone',
#  294: 'together',
#  295: 'watched',
#  296: 'play',
#  297: 'american',
#  298: 'plays',
#  299: '1',
#  300: 'said',
#  301: 'effects',
#  302: 'later',
#  303: 'takes',
#  304: 'instead',
#  305: 'seem',
#  306: 'beautiful',
#  307: 'john',
#  308: 'himself',
#  309: 'version',
#  310: 'audience',
#  311: 'high',
#  312: 'house',
#  313: 'night',
#  314: 'during',
#  315: 'everyone',
#  316: 'left',
#  317: 'special',
#  318: 'seeing',
#  319: 'half',
#  320: 'excellent',
#  321: 'wife',
#  322: 'star',
#  323: 'shot',
#  324: 'war',
#  325: 'idea',
#  326: 'nice',
#  327: 'black',
#  328: 'less',
#  329: 'mind',
#  330: 'simply',
#  331: 'read',
#  332: 'second',
#  333: 'else',
#  334: "you're",
#  335: 'father',
#  336: 'fan',
#  337: 'poor',
#  338: 'help',
#  339: 'completely',
#  340: 'death',
#  341: '3',
#  342: 'used',
#  343: 'home',
#  344: 'either',
#  345: 'short',
#  346: 'line',
#  347: 'given',
#  348: 'men',
#  349: 'top',
#  350: 'dead',
#  351: 'budget',
#  352: 'try',
#  353: 'performances',
#  354: 'wrong',
#  355: 'classic',
#  356: 'boring',
#  357: 'enjoy',
#  358: 'need',
#  359: 'rest',
#  360: 'use',
#  361: 'kids',
#  362: 'hollywood',
#  363: 'low',
#  364: 'production',
#  365: 'until',
#  366: 'along',
#  367: 'full',
#  368: 'friends',
#  369: 'camera',
#  370: 'truly',
#  371: 'women',
#  372: 'awful',
#  373: 'video',
#  374: 'next',
#  375: 'tell',
#  376: 'remember',
#  377: 'couple',
#  378: 'stupid',
#  379: 'start',
#  380: 'stars',
#  381: 'perhaps',
#  382: 'sex',
#  383: 'mean',
#  384: 'came',
#  385: 'recommend',
#  386: 'let',
#  387: 'moments',
#  388: 'wonderful',
#  389: 'episode',
#  390: 'understand',
#  391: 'small',
#  392: 'face',
#  393: 'terrible',
#  394: 'playing',
#  395: 'school',
#  396: 'getting',
#  397: 'written',
#  398: 'doing',
#  399: 'often',
#  400: 'keep',
#  401: 'early',
#  402: 'name',
#  403: 'perfect',
#  404: 'style',
#  405: 'human',
#  406: 'definitely',
#  407: 'gives',
#  408: 'others',
#  409: 'itself',
#  410: 'lines',
#  411: 'live',
#  412: 'become',
#  413: 'dialogue',
#  414: 'person',
#  415: 'lost',
#  416: 'finally',
#  417: 'piece',
#  418: 'head',
#  419: 'case',
#  420: 'felt',
#  421: 'yes',
#  422: 'liked',
#  423: 'supposed',
#  424: 'title',
#  425: "couldn't",
#  426: 'absolutely',
#  427: 'white',
#  428: 'against',
#  429: 'boy',
#  430: 'picture',
#  431: 'sort',
#  432: 'worse',
#  433: 'certainly',
#  434: 'went',
#  435: 'entire',
#  436: 'waste',
#  437: 'cinema',
#  438: 'problem',
#  439: 'hope',
#  440: 'entertaining',
#  441: "she's",
#  442: 'mr',
#  443: 'overall',
#  444: 'evil',
#  445: 'called',
#  446: 'loved',
#  447: 'based',
#  448: 'oh',
#  449: 'several',
#  450: 'fans',
#  451: 'mother',
#  452: 'drama',
#  453: 'beginning',
#  454: 'killer',
#  455: 'lives',
#  456: '5',
#  457: 'direction',
#  458: 'care',
#  459: 'already',
#  460: 'becomes',
#  461: 'laugh',
#  462: 'example',
#  463: 'friend',
#  464: 'dark',
#  465: 'despite',
#  466: 'under',
#  467: 'seemed',
#  468: 'throughout',
#  469: '4',
#  470: 'turn',
#  471: 'unfortunately',
#  472: 'wanted',
#  473: "i'd",
#  474: '\x96',
#  475: 'children',
#  476: 'final',
#  477: 'fine',
#  478: 'history',
#  479: 'amazing',
#  480: 'sound',
#  481: 'guess',
#  482: 'heart',
#  483: 'totally',
#  484: 'lead',
#  485: 'humor',
#  486: 'writing',
#  487: 'michael',
#  488: 'quality',
#  489: "you'll",
#  490: 'close',
#  491: 'son',
#  492: 'guys',
#  493: 'wants',
#  494: 'works',
#  495: 'behind',
#  496: 'tries',
#  497: 'art',
#  498: 'side',
#  499: 'game',
#  500: 'past',
#  501: 'able',
#  502: 'b',
#  503: 'days',
#  504: 'turns',
#  505: 'child',
#  506: "they're",
#  507: 'hand',
#  508: 'flick',
#  509: 'enjoyed',
#  510: 'act',
#  511: 'genre',
#  512: 'town',
#  513: 'favorite',
#  514: 'soon',
#  515: 'kill',
#  516: 'starts',
#  517: 'sometimes',
#  518: 'car',
#  519: 'gave',
#  520: 'run',
#  521: 'late',
#  522: 'eyes',
#  523: 'actress',
#  524: 'etc',
#  525: 'directed',
#  526: 'horrible',
#  527: "won't",
#  528: 'viewer',
#  529: 'brilliant',
#  530: 'parts',
#  531: 'self',
#  532: 'themselves',
#  533: 'hour',
#  534: 'expect',
#  535: 'thinking',
#  536: 'stories',
#  537: 'stuff',
#  538: 'girls',
#  539: 'obviously',
#  540: 'blood',
#  541: 'decent',
#  542: 'city',
#  543: 'voice',
#  544: 'highly',
#  545: 'myself',
#  546: 'feeling',
#  547: 'fight',
#  548: 'except',
#  549: 'slow',
#  550: 'matter',
#  551: 'type',
#  552: 'anyway',
#  553: 'kid',
#  554: 'roles',
#  555: 'killed',
#  556: 'heard',
#  557: 'god',
#  558: 'age',
#  559: 'says',
#  560: 'moment',
#  561: 'took',
#  562: 'leave',
#  563: 'writer',
#  564: 'strong',
#  565: 'cannot',
#  566: 'violence',
#  567: 'police',
#  568: 'hit',
#  569: 'stop',
#  570: 'happens',
#  571: 'particularly',
#  572: 'known',
#  573: 'involved',
#  574: 'happened',
#  575: 'extremely',
#  576: 'daughter',
#  577: 'obvious',
#  578: 'told',
#  579: 'chance',
#  580: 'living',
#  581: 'coming',
#  582: 'lack',
#  583: 'alone',
#  584: 'experience',
#  585: "wouldn't",
#  586: 'including',
#  587: 'murder',
#  588: 'attempt',
#  589: 's',
#  590: 'please',
#  591: 'james',
#  592: 'happen',
#  593: 'wonder',
#  594: 'crap',
#  595: 'ago',
#  596: 'brother',
#  597: "film's",
#  598: 'gore',
#  599: 'none',
#  600: 'complete',
#  601: 'interest',
#  602: 'score',
#  603: 'group',
#  604: 'cut',
#  605: 'simple',
#  606: 'save',
#  607: 'ok',
#  608: 'hell',
#  609: 'looked',
#  610: 'career',
#  611: 'number',
#  612: 'song',
#  613: 'possible',
#  614: 'seriously',
#  615: 'annoying',
#  616: 'shown',
#  617: 'exactly',
#  618: 'sad',
#  619: 'running',
#  620: 'musical',
#  621: 'serious',
#  622: 'taken',
#  623: 'yourself',
#  624: 'whose',
#  625: 'released',
#  626: 'cinematography',
#  627: 'david',
#  628: 'scary',
#  629: 'ends',
#  630: 'english',
#  631: 'hero',
#  632: 'usually',
#  633: 'hours',
#  634: 'reality',
#  635: 'opening',
#  636: "i'll",
#  637: 'across',
#  638: 'today',
#  639: 'jokes',
#  640: 'light',
#  641: 'hilarious',
#  642: 'somewhat',
#  643: 'usual',
#  644: 'started',
#  645: 'cool',
#  646: 'ridiculous',
#  647: 'body',
#  648: 'relationship',
#  649: 'view',
#  650: 'level',
#  651: 'opinion',
#  652: 'change',
#  653: 'happy',
#  654: 'middle',
#  655: 'taking',
#  656: 'wish',
#  657: 'husband',
#  658: 'finds',
#  659: 'saying',
#  660: 'order',
#  661: 'talking',
#  662: 'ones',
#  663: 'documentary',
#  664: 'shots',
#  665: 'huge',
#  666: 'novel',
#  667: 'female',
#  668: 'mostly',
#  669: 'robert',
#  670: 'power',
#  671: 'episodes',
#  672: 'room',
#  673: 'important',
#  674: 'rating',
#  675: 'talent',
#  676: 'five',
#  677: 'major',
#  678: 'turned',
#  679: 'strange',
#  680: 'word',
#  681: 'modern',
#  682: 'call',
#  683: 'apparently',
#  684: 'disappointed',
#  685: 'single',
#  686: 'events',
#  687: 'due',
#  688: 'four',
#  689: 'songs',
#  690: 'basically',
#  691: 'attention',
#  692: '7',
#  693: 'knows',
#  694: 'clearly',
#  695: 'supporting',
#  696: 'knew',
#  697: 'british',
#  698: 'television',
#  699: 'comic',
#  700: 'non',
#  701: 'fast',
#  702: 'earth',
#  703: 'country',
#  704: 'future',
#  705: 'cheap',
#  706: 'class',
#  707: 'thriller',
#  708: '8',
#  709: 'silly',
#  710: 'king',
#  711: 'problems',
#  712: "aren't",
#  713: 'easily',
#  714: 'words',
#  715: 'tells',
#  716: 'miss',
#  717: 'jack',
#  718: 'local',
#  719: 'sequence',
#  720: 'bring',
#  721: 'entertainment',
#  722: 'paul',
#  723: 'beyond',
#  724: 'upon',
#  725: 'whether',
#  726: 'predictable',
#  727: 'moving',
#  728: 'similar',
#  729: 'straight',
#  730: 'romantic',
#  731: 'sets',
#  732: 'review',
#  733: 'falls',
#  734: 'oscar',
#  735: 'mystery',
#  736: 'enjoyable',
#  737: 'needs',
#  738: 'appears',
#  739: 'talk',
#  740: 'rock',
#  741: 'george',
#  742: 'giving',
#  743: 'eye',
#  744: 'richard',
#  745: 'within',
#  746: 'ten',
#  747: 'animation',
#  748: 'message',
#  749: 'theater',
#  750: 'near',
#  751: 'above',
#  752: 'dull',
#  753: 'nearly',
#  754: 'sequel',
#  755: 'theme',
#  756: 'points',
#  757: "'",
#  758: 'stand',
#  759: 'mention',
#  760: 'lady',
#  761: 'bunch',
#  762: 'add',
#  763: 'feels',
#  764: 'herself',
#  765: 'release',
#  766: 'red',
#  767: 'team',
#  768: 'storyline',
#  769: 'surprised',
#  770: 'ways',
#  771: 'using',
#  772: 'named',
#  773: "haven't",
#  774: 'lots',
#  775: 'easy',
#  776: 'fantastic',
#  777: 'begins',
#  778: 'actual',
#  779: 'working',
#  780: 'effort',
#  781: 'york',
#  782: 'die',
#  783: 'hate',
#  784: 'french',
#  785: 'minute',
#  786: 'tale',
#  787: 'clear',
#  788: 'stay',
#  789: '9',
#  790: 'elements',
#  791: 'feature',
#  792: 'among',
#  793: 'follow',
#  794: 'comments',
#  795: 're',
#  796: 'viewers',
#  797: 'avoid',
#  798: 'sister',
#  799: 'showing',
#  800: 'typical',
#  801: 'editing',
#  802: "what's",
#  803: 'famous',
#  804: 'tried',
#  805: 'sorry',
#  806: 'dialog',
#  807: 'check',
#  808: 'fall',
#  809: 'period',
#  810: 'season',
#  811: 'form',
#  812: 'certain',
#  813: 'filmed',
#  814: 'weak',
#  815: 'soundtrack',
#  816: 'means',
#  817: 'buy',
#  818: 'material',
#  819: 'somehow',
#  820: 'realistic',
#  821: 'figure',
#  822: 'crime',
#  823: 'doubt',
#  824: 'gone',
#  825: 'peter',
#  826: 'tom',
#  827: 'kept',
#  828: 'viewing',
#  829: 't',
#  830: 'general',
#  831: 'leads',
#  832: 'greatest',
#  833: 'space',
#  834: 'lame',
#  835: 'suspense',
#  836: 'dance',
#  837: 'imagine',
#  838: 'brought',
#  839: 'third',
#  840: 'atmosphere',
#  841: 'hear',
#  842: 'particular',
#  843: 'sequences',
#  844: 'whatever',
#  845: 'parents',
#  846: 'move',
#  847: 'lee',
#  848: 'indeed',
#  849: 'learn',
#  850: 'rent',
#  851: 'de',
#  852: 'eventually',
#  853: 'note',
#  854: 'deal',
#  855: 'average',
#  856: 'reviews',
#  857: 'wait',
#  858: 'forget',
#  859: 'japanese',
#  860: 'sexual',
#  861: 'poorly',
#  862: 'premise',
#  863: 'okay',
#  864: 'zombie',
#  865: 'surprise',
#  866: 'believable',
#  867: 'stage',
#  868: 'possibly',
#  869: 'sit',
#  870: "who's",
#  871: 'decided',
#  872: 'expected',
#  873: "you've",
#  874: 'subject',
#  875: 'nature',
#  876: 'became',
#  877: 'difficult',
#  878: 'free',
#  879: 'killing',
#  880: 'screenplay',
#  881: 'truth',
#  882: 'romance',
#  883: 'dr',
#  884: 'nor',
#  885: 'reading',
#  886: 'needed',
#  887: 'question',
#  888: 'leaves',
#  889: 'street',
#  890: '20',
#  891: 'meets',
#  892: 'hot',
#  893: 'unless',
#  894: 'begin',
#  895: 'baby',
#  896: 'superb',
#  897: 'credits',
#  898: 'imdb',
#  899: 'otherwise',
#  900: 'write',
#  901: 'shame',
#  902: "let's",
#  903: 'situation',
#  904: 'dramatic',
#  905: 'memorable',
#  906: 'directors',
#  907: 'earlier',
#  908: 'meet',
#  909: 'disney',
#  910: 'open',
#  911: 'dog',
#  912: 'badly',
#  913: 'joe',
#  914: 'male',
#  915: 'weird',
#  916: 'acted',
#  917: 'forced',
#  918: 'laughs',
#  919: 'sci',
#  920: 'emotional',
#  921: 'older',
#  922: 'realize',
#  923: 'fi',
#  924: 'dream',
#  925: 'society',
#  926: 'writers',
#  927: 'interested',
#  928: 'footage',
#  929: 'forward',
#  930: 'comment',
#  931: 'crazy',
#  932: 'deep',
#  933: 'sounds',
#  934: 'plus',
#  935: 'beauty',
#  936: 'whom',
#  937: 'america',
#  938: 'fantasy',
#  939: 'directing',
#  940: 'keeps',
#  941: 'ask',
#  942: 'development',
#  943: 'features',
#  944: 'air',
#  945: 'quickly',
#  946: 'mess',
#  947: 'creepy',
#  948: 'towards',
#  949: 'perfectly',
#  950: 'mark',
#  951: 'worked',
#  952: 'box',
#  953: 'cheesy',
#  954: 'unique',
#  955: 'setting',
#  956: 'hands',
#  957: 'plenty',
#  958: 'result',
#  959: 'previous',
#  960: 'brings',
#  961: 'effect',
#  962: 'e',
#  963: 'total',
#  964: 'personal',
#  965: 'incredibly',
#  966: 'rate',
#  967: 'fire',
#  968: 'monster',
#  969: 'business',
#  970: 'leading',
#  971: 'apart',
#  972: 'casting',
#  973: 'admit',
#  974: 'joke',
#  975: 'powerful',
#  976: 'appear',
#  977: 'background',
#  978: 'telling',
#  979: 'girlfriend',
#  980: 'meant',
#  981: 'christmas',
#  982: 'hardly',
#  983: 'present',
#  984: 'battle',
#  985: 'potential',
#  986: 'create',
#  987: 'bill',
#  988: 'break',
#  989: 'pay',
#  990: 'masterpiece',
#  991: 'gay',
#  992: 'political',
#  993: 'return',
#  994: 'dumb',
#  995: 'fails',
#  996: 'fighting',
#  997: 'various',
#  998: 'era',
#  999: 'portrayed',
#  ...}

# %% [markdown]
# Padding for input LSTM models

# %%
# maxlen: determine the length of the output arrays, padding and trimming
maxlen = 200

# %%
x_train = sequence.pad_sequences(x_train, maxlen=maxlen, truncating="post", padding="post", value=padding_id)

# %%
x_test = sequence.pad_sequences(x_test, maxlen=maxlen, truncating="post", padding="post", value=padding_id)

# %% [markdown]
# ### Step 2. Create Attention Layer
#
# Attention helps to keep information in long sequence.

# %%
class Attention(tf.keras.Model):
    
    def __init__(self, units):
        # initialize initial values
        super(Attention, self).__init__()
        # architecture of nn
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)
        
    def call(self, features, hidden):
        hidden_with_time_axis = tf.expand_dims(hidden, 1)
        prob_score = tf.nn.tanh(self.W1(features) + self.W2(hidden_with_time_axis))
        attention_weights = tf.nn.softmax(self.V(prob_score), axis=1)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

# %% [markdown]
# 前提: ニューラルネットワークは線形代数と非線形活性化関数からの演算子の合成です。

# %% [markdown]
# ### Step 3. Embed Layer
#
# *Function*: Embed words as a vector of numbers.
#
# *Method*: Random Initialization by Embedding Layer
# (Other choices:  Word2Vec, GloVe, Fast Text, doc2vec, lda2vec)

# %%
sequence_input = Input(shape=(maxlen, ), dtype="int32")
embedded_sequence = keras.layers.Embedding(input_dim=vocab_size, 
                                           output_dim=128, 
                                           input_length=maxlen)(sequence_input)

# %% [markdown]
# ### Step 4. Bi-directional Recurrent neural network

# %%
import os

rnn_cell_size = 128

# %%
lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(units=rnn_cell_size,
                                                          dropout=0.3,
                                                          return_sequences=True,
                                                          return_state=True,
                                                          recurrent_activation="relu",
                                                          recurrent_initializer="glorot_uniform"),
                                     name="bi_lstm_0")(embedded_sequence)

# %%
lstm, forward_h, forward_c, backward_h, backward_c = tf.keras.layers.Bidirectional \
                                                            (tf.keras.layers.LSTM
                                                             (rnn_cell_size, 
                                                              dropout=0.2,
                                                              return_sequences=True,
                                                              return_state=True,
                                                              recurrent_activation="relu",
                                                              recurrent_initializer="glorot_uniform"))(lstm)

# %% [markdown]
# Concatenate the hidden states from each RNN

# %%
from tensorflow.python.keras.layers import Concatenate

# %%
state_h = Concatenate()([forward_h, backward_h])
state_c = Concatenate()([forward_c, backward_c])
 
context_vector, attention_weights = Attention()
 
output = keras.layers.Dense(1, activation='sigmoid')(context_vector)
 
model = keras.Model(inputs=sequence_input, outputs=output)

# summarize layers
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-cf4cedd8b7f5> in <module>
#       2 state_c = Concatenate()([forward_c, backward_c])
#       3
# ----> 4 context_vector, attention_weights = Attention()
#       5
#       6 output = keras.layers.Dense(1, activation='sigmoid')(context_vector)
#
# TypeError: __init__() missing 1 required positional argument: 'units'

# %% [markdown]
# Multi-layer もあるよ！

# %%
model.compile(optimizer=tf.train.AdamOptimizer(),
              loss='binary_crossentropy',
              metrics=['accuracy'])
 
early_stopping_callback = keras.callbacks.EarlyStopping(monitor='val_loss',
                                                        min_delta=0,
                                                        patience=1,
                                                        verbose=0, mode='auto')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-e413ac6e2d8c> in <module>
# ----> 1 model.compile(optimizer=tf.train.AdamOptimizer(),
#       2               loss='binary_crossentropy',
#       3               metrics=['accuracy'])
#       4
#       5 early_stopping_callback = keras.callbacks.EarlyStopping(monitor='val_loss',
#
# NameError: name 'model' is not defined

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=10,
                    batch_size=200,
                    validation_split=.3, verbose=1, callbacks=[early_stopping_callback])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-ea0488233572> in <module>
# ----> 1 history = model.fit(x_train,
#       2                     y_train,
#       3                     epochs=10,
#       4                     batch_size=200,
#       5                     validation_split=.3, verbose=1, callbacks=[early_stopping_callback])
#
# NameError: name 'model' is not defined

# %%
result = model.evaluate(x_test, y_test)
print(result)
